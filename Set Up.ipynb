# %% [markdown]
# # Getting Started
#
# ## Background:
# Cloud Services and Data Accessbility are a major part of moving forward with Open Science. A major component of open science is that all data should be accessible for research and applications. The Physical Oceanography Distributed Active Center (PO.DAAC) is actively involved in making all data available through the Amazon Web Services (AWS) cloud. PO.DAAC has developed tools and services that allow for accessing data on the cloud. With the launch of NASA’s Surface Water Ocean Topography Mission (SWOT) the issue of Big Data and accessibility will become a major
# component of data accessibility through AWS.
#
# ## Objectives:
# The major objective of the work will be to work directly with the PO.DAAC tools and services that allow for access through AWS. The primary goal will be to understand issues of data accessibility through the cloud as well as documenting a test case through the application to the Gulf of Mexico. What tools and services were used for the study that made the analysis accessible.

# %% [markdown]
# # 1. Creating Earthdata login:
#
# ![Screenshot%202023-03-28%20230812.png](attachment:Screenshot%202023-03-28%20230812.png)
#
# This will give you access to the data collected from NASA's Satellites
#
# More information on this can be found at : https://www.earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/earthdata-login

# %% [markdown]
# # 2. Installing Jupyter
#
# For those not familiar with Jupyter Notebooks, it is a software that is able to combine code and text for easier documentation of data. The author recommends the installation of the Anaconda package. This package already includes the jupyter notebook software and a plethora of python libraries.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Keep in mind that when accessing Jupyter, there are two options: Jupyter Notebook and Jupyterlab. While both are able to be installed and can be run in the browser, JupyterLab has a wider range of capabilities when compared to it's counterpart. To access JupeterLab, open the Anaconda prompt

# %% [markdown]
# ![Screenshot%202023-03-28%20234035.png](attachment:Screenshot%202023-03-28%20234035.png)

# %% [markdown]
# Install JupyterLab with pip:
#
# pip install jupyterlab
#
# Once installed, launch JupyterLab with:
#
# jupyter-lab

# %% [markdown]
# # 3. netrc file
#
# Depending on what data you want to access and where, the netrc file will look different. This file should be in the home directory and containyour login information for Earthdata. More inofrmation on how to create this file, can be found here: https://nasa-openscapes.github.io/2021-Cloud-Hackathon/tutorials/04_NASA_Earthdata_Authentication.html#authentication-via-netrc-file

# %% [markdown]
# The file should be in the following format:
#
# machine urs.earthdata.nasa.gov <br>
# login "username" <br>
# password "password"
#
# **notice** the netrc file's format may change when trying to access cloud data

# %% [markdown]
# # 4. Useful tips for getting started

# %% [markdown]
# In the Anaconda prompt, Download the following packages:<br>
#     pip install s3fs<br>
#     pip install harmony-pytorch<br>
#     pip install netCDF4<br>
#     pip install xarray
